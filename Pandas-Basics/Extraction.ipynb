# %%
import pandas as pd

# %%
import pandas as pd
import os
from kaggle.api.kaggle_api_extended import KaggleApi

api = KaggleApi()
api.authenticate()

dataset_url = 'funxexcel/retail-data-customer-summary-learn-pandas-basics'
api.dataset_download_file(dataset_url, file_name='Retail_Data_Customers_Summary.csv', path='./')

df = pd.read_csv('Retail_Data_Customers_Summary.csv')
# Out:
# Dataset URL: https://www.kaggle.com/datasets/funxexcel/retail-data-customer-summary-learn-pandas-basics

# %%
# df.count()

# %%
#find top 5 customers
# df.head()

# %%
#sort by column
# df= df.sort_values(by=['tran_amount_2015'], ascending=False) 
# df = df.sort_values(by = ['tran_amount_2015'], ascending = False).head(5)
# df

# %%
# df = df.sort_index(ascending=False)
# df.head(5)

# %%
#Find top customers in 2014 that did not buy in 2015
# df = df.sort_values(by=['tran_amount_2014'], ascending=False).head()

# %%
# df = df.reset_index(drop=True)
# df

# %%
# df.head(5)

# %%
#We will store in a new dataframe name
# customers_2014 = df.sort_values(by = ['tran_amount_2014'], ascending = False).head(5)
# customers_2014

# %%
#select relevant column to know 
# customers_2014[['customer_id', 'tran_amount_2014', 'tran_amount_2015']]

# %%
df
# Out:
#      customer_id  tran_amount_2011  tran_amount_2012  tran_amount_2013  \
# 0         CS2945             153.0             516.0             173.0
# 1         CS4074             269.0             429.0             737.0
# 2         CS4798             153.0             536.0             414.0
# 3         CS4424             547.0             380.0             921.0
# 4         CS5057             290.0             235.0             509.0
# ...          ...               ...               ...               ...
# 6884      CS8633             143.0             168.0             122.0
# 6885      CS8667              44.0             178.0              85.0
# 6886      CS8740              55.0             218.0              17.0
# 6887      CS8753             126.0             289.0              82.0
# 6888      CS8760             106.0              71.0              59.0
#
#       tran_amount_2014  tran_amount_2015  transactions_2011  \
# 0               1029.0              40.0                2.0
# 1               1027.0               NaN                3.0
# 2               1001.0              47.0                2.0
# 3                984.0             101.0                7.0
# 4                974.0               NaN                4.0
# ...                ...               ...                ...
# 6884               NaN               NaN                4.0
# 6885               NaN               NaN                1.0
# 6886               NaN               NaN                2.0
# 6887               NaN               NaN                3.0
# 6888               NaN               NaN                2.0
#
#       transactions_2012  transactions_2013  transactions_2014  \
# 0                   7.0                3.0               13.0
# 1                   6.0               10.0               15.0
# 2                   7.0                6.0               11.0
# 3                   5.0               13.0               13.0
# 4                   4.0                6.0               12.0
# ...                 ...                ...                ...
# 6884                4.0                4.0                NaN
# 6885                3.0                2.0                NaN
# 6886                4.0                1.0                NaN
# 6887                6.0                2.0                NaN
# 6888                3.0                2.0                NaN
#
#       transactions_2015 First_Transaction Latest_Transaction
# 0                   1.0         18-May-11          08-Mar-15
# 1                   NaN         29-May-11          05-Dec-14
# 2                   1.0         01-Jul-11          21-Feb-15
# 3                   1.0         25-May-11          19-Jan-15
# 4                   NaN         10-Jul-11          02-Dec-14
# ...                 ...               ...                ...
# 6884                NaN         28-Jul-11          14-Nov-13
# 6885                NaN         01-Sep-11          26-Sep-13
# 6886                NaN         30-Oct-11          02-Dec-13
# 6887                NaN         08-Aug-11          08-Mar-13
# 6888                NaN         27-May-11          24-Dec-13
#
# [6889 rows x 13 columns]

# %%
df.head()
# Out:
#   customer_id  tran_amount_2011  tran_amount_2012  tran_amount_2013  \
# 0      CS2945             153.0             516.0             173.0
# 1      CS4074             269.0             429.0             737.0
# 2      CS4798             153.0             536.0             414.0
# 3      CS4424             547.0             380.0             921.0
# 4      CS5057             290.0             235.0             509.0
#
#    tran_amount_2014  tran_amount_2015  transactions_2011  transactions_2012  \
# 0            1029.0              40.0                2.0                7.0
# 1            1027.0               NaN                3.0                6.0
# 2            1001.0              47.0                2.0                7.0
# 3             984.0             101.0                7.0                5.0
# 4             974.0               NaN                4.0                4.0
#
#    transactions_2013  transactions_2014  transactions_2015 First_Transaction  \
# 0                3.0               13.0                1.0         18-May-11
# 1               10.0               15.0                NaN         29-May-11
# 2                6.0               11.0                1.0         01-Jul-11
# 3               13.0               13.0                1.0         25-May-11
# 4                6.0               12.0                NaN         10-Jul-11
#
#   Latest_Transaction
# 0          08-Mar-15
# 1          05-Dec-14
# 2          21-Feb-15
# 3          19-Jan-15
# 4          02-Dec-14

# %%
#To find the top 5 customers, we need to sort by tran_amount_2015 in descending order
df.sort_values(by = ['tran_amount_2015'], ascending = False).head()
# Out:
#      customer_id  tran_amount_2011  tran_amount_2012  tran_amount_2013  \
# 2176      CS4871              59.0             551.0             482.0
# 6595      CS1157              46.0             516.0             312.0
# 4871      CS5346             486.0             337.0             312.0
# 4382      CS1802             143.0             314.0             807.0
# 4163      CS5193              94.0             505.0             341.0
#
#       tran_amount_2014  tran_amount_2015  transactions_2011  \
# 2176             376.0             538.0                1.0
# 6595              52.0             501.0                1.0
# 4871             189.0             477.0                7.0
# 4382             223.0             426.0                2.0
# 4163             236.0             410.0                1.0
#
#       transactions_2012  transactions_2013  transactions_2014  \
# 2176                7.0                7.0                5.0
# 6595                8.0                4.0                1.0
# 4871                5.0                4.0                3.0
# 4382                4.0               10.0                4.0
# 4163                7.0                6.0                4.0
#
#       transactions_2015 First_Transaction Latest_Transaction
# 2176                6.0         06-Aug-11          06-Mar-15
# 6595                7.0         30-Dec-11          25-Feb-15
# 4871                6.0         18-May-11          12-Mar-15
# 4382                7.0         30-Aug-11          06-Mar-15
# 4163                6.0         01-Dec-11          28-Feb-15

# %%
#To find the top 5 customers, we need to sort by tran_amount_2014 in descending order
#Then look at the tran_amount_2015 colums to identify those who did not buy
df.sort_values(by = ['tran_amount_2014'], ascending = False).head()
# Out:
#   customer_id  tran_amount_2011  tran_amount_2012  tran_amount_2013  \
# 0      CS2945             153.0             516.0             173.0
# 1      CS4074             269.0             429.0             737.0
# 2      CS4798             153.0             536.0             414.0
# 3      CS4424             547.0             380.0             921.0
# 4      CS5057             290.0             235.0             509.0
#
#    tran_amount_2014  tran_amount_2015  transactions_2011  transactions_2012  \
# 0            1029.0              40.0                2.0                7.0
# 1            1027.0               NaN                3.0                6.0
# 2            1001.0              47.0                2.0                7.0
# 3             984.0             101.0                7.0                5.0
# 4             974.0               NaN                4.0                4.0
#
#    transactions_2013  transactions_2014  transactions_2015 First_Transaction  \
# 0                3.0               13.0                1.0         18-May-11
# 1               10.0               15.0                NaN         29-May-11
# 2                6.0               11.0                1.0         01-Jul-11
# 3               13.0               13.0                1.0         25-May-11
# 4                6.0               12.0                NaN         10-Jul-11
#
#   Latest_Transaction
# 0          08-Mar-15
# 1          05-Dec-14
# 2          21-Feb-15
# 3          19-Jan-15
# 4          02-Dec-14

# %%
#We will store in a new dataframe name
customers_2014 = df.sort_values(by = ['tran_amount_2014'], ascending = False).head()
customers_2014
# Out:
#   customer_id  tran_amount_2011  tran_amount_2012  tran_amount_2013  \
# 0      CS2945             153.0             516.0             173.0
# 1      CS4074             269.0             429.0             737.0
# 2      CS4798             153.0             536.0             414.0
# 3      CS4424             547.0             380.0             921.0
# 4      CS5057             290.0             235.0             509.0
#
#    tran_amount_2014  tran_amount_2015  transactions_2011  transactions_2012  \
# 0            1029.0              40.0                2.0                7.0
# 1            1027.0               NaN                3.0                6.0
# 2            1001.0              47.0                2.0                7.0
# 3             984.0             101.0                7.0                5.0
# 4             974.0               NaN                4.0                4.0
#
#    transactions_2013  transactions_2014  transactions_2015 First_Transaction  \
# 0                3.0               13.0                1.0         18-May-11
# 1               10.0               15.0                NaN         29-May-11
# 2                6.0               11.0                1.0         01-Jul-11
# 3               13.0               13.0                1.0         25-May-11
# 4                6.0               12.0                NaN         10-Jul-11
#
#   Latest_Transaction
# 0          08-Mar-15
# 1          05-Dec-14
# 2          21-Feb-15
# 3          19-Jan-15
# 4          02-Dec-14

# %%
#Then we will select the relevent columns to answer the question
customers_2014[['customer_id','tran_amount_2014','tran_amount_2015']]
# Out:
#   customer_id  tran_amount_2014  tran_amount_2015
# 0      CS2945            1029.0              40.0
# 1      CS4074            1027.0               NaN
# 2      CS4798            1001.0              47.0
# 3      CS4424             984.0             101.0
# 4      CS5057             974.0               NaN

# %%
#sort by NaN position
customers_2014[['customer_id','tran_amount_2014','tran_amount_2015']].sort_values(by = 'tran_amount_2015' , na_position='first')
# Out:
#   customer_id  tran_amount_2014  tran_amount_2015
# 1      CS4074            1027.0               NaN
# 4      CS5057             974.0               NaN
# 0      CS2945            1029.0              40.0
# 2      CS4798            1001.0              47.0
# 3      CS4424             984.0             101.0

# %% [markdown]
# # Select details(all columns) for a given set of customers
# # Concepts covered:
#
# # Indexing Column
# # Slicing Dataframe
# # Selecting Single Row/Multiple Rows (.loc())
# # Making Permanent change to existing dataframe (inplace = True argument)
# Sample Customers: (CS4074, CS5057, CS2945, CS4798, CS4424)

# %%
#so we use .loc to slice/select data by rows
#Still gives an error, as it is unable to find this id in a row (but which row?)
# df.loc['CS4074']

# %% [markdown]
# The error KeyError: 'CS4074' occurs because you are trying to use df.loc['CS4074'], but 'CS4074' is not found in the index of the DataFrame. By default, loc[] looks for the value in the index, not in a column like customer_id

# %%
#The default index is 0,1,2,3,4,5 ...
df.head()
# Out:
#   customer_id  tran_amount_2011  tran_amount_2012  tran_amount_2013  \
# 0      CS2945             153.0             516.0             173.0
# 1      CS4074             269.0             429.0             737.0
# 2      CS4798             153.0             536.0             414.0
# 3      CS4424             547.0             380.0             921.0
# 4      CS5057             290.0             235.0             509.0
#
#    tran_amount_2014  tran_amount_2015  transactions_2011  transactions_2012  \
# 0            1029.0              40.0                2.0                7.0
# 1            1027.0               NaN                3.0                6.0
# 2            1001.0              47.0                2.0                7.0
# 3             984.0             101.0                7.0                5.0
# 4             974.0               NaN                4.0                4.0
#
#    transactions_2013  transactions_2014  transactions_2015 First_Transaction  \
# 0                3.0               13.0                1.0         18-May-11
# 1               10.0               15.0                NaN         29-May-11
# 2                6.0               11.0                1.0         01-Jul-11
# 3               13.0               13.0                1.0         25-May-11
# 4                6.0               12.0                NaN         10-Jul-11
#
#   Latest_Transaction
# 0          08-Mar-15
# 1          05-Dec-14
# 2          21-Feb-15
# 3          19-Jan-15
# 4          02-Dec-14

# %%
# Slicing Rows using (.loc())
#We can select one row by mentioning the index number
df.loc[0]
# Out:
# customer_id              CS2945
# tran_amount_2011          153.0
# tran_amount_2012          516.0
# tran_amount_2013          173.0
# tran_amount_2014         1029.0
# tran_amount_2015           40.0
# transactions_2011           2.0
# transactions_2012           7.0
# transactions_2013           3.0
# transactions_2014          13.0
# transactions_2015           1.0
# First_Transaction     18-May-11
# Latest_Transaction    08-Mar-15
# Name: 0, dtype: object

# %%
# Indexing existing DataFrame
#We need to set index before we could easily select rows (just like setting a primary key in SQL)
df.set_index('customer_id')
# Out:
#              tran_amount_2011  tran_amount_2012  tran_amount_2013  \
# customer_id
# CS2945                  153.0             516.0             173.0
# CS4074                  269.0             429.0             737.0
# CS4798                  153.0             536.0             414.0
# CS4424                  547.0             380.0             921.0
# CS5057                  290.0             235.0             509.0
# ...                       ...               ...               ...
# CS8633                  143.0             168.0             122.0
# CS8667                   44.0             178.0              85.0
# CS8740                   55.0             218.0              17.0
# CS8753                  126.0             289.0              82.0
# CS8760                  106.0              71.0              59.0
#
#              tran_amount_2014  tran_amount_2015  transactions_2011  \
# customer_id
# CS2945                 1029.0              40.0                2.0
# CS4074                 1027.0               NaN                3.0
# CS4798                 1001.0              47.0                2.0
# CS4424                  984.0             101.0                7.0
# CS5057                  974.0               NaN                4.0
# ...                       ...               ...                ...
# CS8633                    NaN               NaN                4.0
# CS8667                    NaN               NaN                1.0
# CS8740                    NaN               NaN                2.0
# CS8753                    NaN               NaN                3.0
# CS8760                    NaN               NaN                2.0
#
#              transactions_2012  transactions_2013  transactions_2014  \
# customer_id
# CS2945                     7.0                3.0               13.0
# CS4074                     6.0               10.0               15.0
# CS4798                     7.0                6.0               11.0
# CS4424                     5.0               13.0               13.0
# CS5057                     4.0                6.0               12.0
# ...                        ...                ...                ...
# CS8633                     4.0                4.0                NaN
# CS8667                     3.0                2.0                NaN
# CS8740                     4.0                1.0                NaN
# CS8753                     6.0                2.0                NaN
# CS8760                     3.0                2.0                NaN
#
#              transactions_2015 First_Transaction Latest_Transaction
# customer_id
# CS2945                     1.0         18-May-11          08-Mar-15
# CS4074                     NaN         29-May-11          05-Dec-14
# CS4798                     1.0         01-Jul-11          21-Feb-15
# CS4424                     1.0         25-May-11          19-Jan-15
# CS5057                     NaN         10-Jul-11          02-Dec-14
# ...                        ...               ...                ...
# CS8633                     NaN         28-Jul-11          14-Nov-13
# CS8667                     NaN         01-Sep-11          26-Sep-13
# CS8740                     NaN         30-Oct-11          02-Dec-13
# CS8753                     NaN         08-Aug-11          08-Mar-13
# CS8760                     NaN         27-May-11          24-Dec-13
#
# [6889 rows x 12 columns]

# %%
#When we see above the index is set. However, when we check its reset to default
df.head()
# Out:
#   customer_id  tran_amount_2011  tran_amount_2012  tran_amount_2013  \
# 0      CS2945             153.0             516.0             173.0
# 1      CS4074             269.0             429.0             737.0
# 2      CS4798             153.0             536.0             414.0
# 3      CS4424             547.0             380.0             921.0
# 4      CS5057             290.0             235.0             509.0
#
#    tran_amount_2014  tran_amount_2015  transactions_2011  transactions_2012  \
# 0            1029.0              40.0                2.0                7.0
# 1            1027.0               NaN                3.0                6.0
# 2            1001.0              47.0                2.0                7.0
# 3             984.0             101.0                7.0                5.0
# 4             974.0               NaN                4.0                4.0
#
#    transactions_2013  transactions_2014  transactions_2015 First_Transaction  \
# 0                3.0               13.0                1.0         18-May-11
# 1               10.0               15.0                NaN         29-May-11
# 2                6.0               11.0                1.0         01-Jul-11
# 3               13.0               13.0                1.0         25-May-11
# 4                6.0               12.0                NaN         10-Jul-11
#
#   Latest_Transaction
# 0          08-Mar-15
# 1          05-Dec-14
# 2          21-Feb-15
# 3          19-Jan-15
# 4          02-Dec-14

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
# Set 'customer_id' as the index without assigning it to a variable
df.set_index('customer_id', inplace=True)

# Verify the index has been set
print(df.head())
# Out:
#              tran_amount_2011  tran_amount_2012  tran_amount_2013  \
# customer_id
# CS2945                  153.0             516.0             173.0
# CS4074                  269.0             429.0             737.0
# CS4798                  153.0             536.0             414.0
# CS4424                  547.0             380.0             921.0
# CS5057                  290.0             235.0             509.0
#
#              tran_amount_2014  tran_amount_2015  transactions_2011  \
# customer_id
# CS2945                 1029.0              40.0                2.0
# CS4074                 1027.0               NaN                3.0
# CS4798                 1001.0              47.0                2.0
# CS4424                  984.0             101.0                7.0
# CS5057                  974.0               NaN                4.0
#
#              transactions_2012  transactions_2013  transactions_2014  \
# customer_id
# CS2945                     7.0                3.0               13.0
# CS4074                     6.0               10.0               15.0
# CS4798                     7.0                6.0               11.0
# CS4424                     5.0               13.0               13.0
# CS5057                     4.0                6.0               12.0
#
#              transactions_2015 First_Transaction Latest_Transaction
# customer_id
# CS2945                     1.0         18-May-11          08-Mar-15
# CS4074                     NaN         29-May-11          05-Dec-14
# CS4798                     1.0         01-Jul-11          21-Feb-15
# CS4424                     1.0         25-May-11          19-Jan-15
# CS5057                     NaN         10-Jul-11          02-Dec-14

# %%
#Now the change is permanent
df.head()
# Out:
#              tran_amount_2011  tran_amount_2012  tran_amount_2013  \
# customer_id
# CS2945                  153.0             516.0             173.0
# CS4074                  269.0             429.0             737.0
# CS4798                  153.0             536.0             414.0
# CS4424                  547.0             380.0             921.0
# CS5057                  290.0             235.0             509.0
#
#              tran_amount_2014  tran_amount_2015  transactions_2011  \
# customer_id
# CS2945                 1029.0              40.0                2.0
# CS4074                 1027.0               NaN                3.0
# CS4798                 1001.0              47.0                2.0
# CS4424                  984.0             101.0                7.0
# CS5057                  974.0               NaN                4.0
#
#              transactions_2012  transactions_2013  transactions_2014  \
# customer_id
# CS2945                     7.0                3.0               13.0
# CS4074                     6.0               10.0               15.0
# CS4798                     7.0                6.0               11.0
# CS4424                     5.0               13.0               13.0
# CS5057                     4.0                6.0               12.0
#
#              transactions_2015 First_Transaction Latest_Transaction
# customer_id
# CS2945                     1.0         18-May-11          08-Mar-15
# CS4074                     NaN         29-May-11          05-Dec-14
# CS4798                     1.0         01-Jul-11          21-Feb-15
# CS4424                     1.0         25-May-11          19-Jan-15
# CS5057                     NaN         10-Jul-11          02-Dec-14

# %%
# df.loc['CS2945']

# %%
#To get details of 5 customers, we use a list 
df.loc[['CS4074', 'CS5057', 'CS2945', 'CS4798', 'CS4424']]
# Out:
#              tran_amount_2011  tran_amount_2012  tran_amount_2013  \
# customer_id
# CS4074                  269.0             429.0             737.0
# CS5057                  290.0             235.0             509.0
# CS2945                  153.0             516.0             173.0
# CS4798                  153.0             536.0             414.0
# CS4424                  547.0             380.0             921.0
#
#              tran_amount_2014  tran_amount_2015  transactions_2011  \
# customer_id
# CS4074                 1027.0               NaN                3.0
# CS5057                  974.0               NaN                4.0
# CS2945                 1029.0              40.0                2.0
# CS4798                 1001.0              47.0                2.0
# CS4424                  984.0             101.0                7.0
#
#              transactions_2012  transactions_2013  transactions_2014  \
# customer_id
# CS4074                     6.0               10.0               15.0
# CS5057                     4.0                6.0               12.0
# CS2945                     7.0                3.0               13.0
# CS4798                     7.0                6.0               11.0
# CS4424                     5.0               13.0               13.0
#
#              transactions_2015 First_Transaction Latest_Transaction
# customer_id
# CS4074                     NaN         29-May-11          05-Dec-14
# CS5057                     NaN         10-Jul-11          02-Dec-14
# CS2945                     1.0         18-May-11          08-Mar-15
# CS4798                     1.0         01-Jul-11          21-Feb-15
# CS4424                     1.0         25-May-11          19-Jan-15

# %%
# Select 2015 transaction amount and number of transcactions for the same customers
# Selecting multiple columns and rows using (.loc())
# Erasing index for a DataFrame (reset_index())

#We can extend .loc to select both rows and columns (begin with list customers from rows then select columns)

df.loc[['CS4074', 'CS5057', 'CS2945', 'CS4798', 'CS4424'], ['tran_amount_2014', 'tran_amount_2015']]
# Out:
#              tran_amount_2014  tran_amount_2015
# customer_id
# CS4074                 1027.0               NaN
# CS5057                  974.0               NaN
# CS2945                 1029.0              40.0
# CS4798                 1001.0              47.0
# CS4424                  984.0             101.0

# %%
# Erasing index for a DataFrame (reset_index())
df.reset_index(inplace = True)

# %%
df.loc[['CS4074', 'CS5057', 'CS2945', 'CS4798', 'CS4424'], ['tran_amount_2014', 'tran_amount_2015']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[163], line 1
# ----> 1 df.loc[['CS4074', 'CS5057', 'CS2945', 'CS4798', 'CS4424'], ['tran_amount_2014', 'tran_amount_2015']]
#
# File c:\Users\RAKSHITA\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexing.py:1184, in _LocationIndexer.__getitem__(self, key)
#    1182     if self._is_scalar_access(key):
#    1183         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1184     return self._getitem_tuple(key)
#    1185 else:
#    1186     # we by definition only have the 0th axis
#    1187     axis = self.axis or 0
#
# File c:\Users\RAKSHITA\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexing.py:1375, in _LocIndexer._getitem_tuple(self, tup)
#    1373 # ugly hack for GH #836
#    1374 if self._multi_take_opportunity(tup):
# -> 1375     return self._multi_take(tup)
#    1377 return self._getitem_tuple_same_dim(tup)
#
# File c:\Users\RAKSHITA\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexing.py:1327, in _LocIndexer._multi_take(self, tup)
#    1310 """
#    1311 Create the indexers for the passed tuple of keys, and
#    1312 executes the take operation. This allows the take operation to be
#    (...)
#    1323 values: same type as the object being indexed
#    1324 """
#    1325 # GH 836
#    1326 d = {
# -> 1327     axis: self._get_listlike_indexer(key, axis)
#    1328     for (key, axis) in zip(tup, self.obj._AXIS_ORDERS)
#    1329 }
#    1330 return self.obj._reindex_with_indexers(d, copy=True, allow_dups=True)
#
# File c:\Users\RAKSHITA\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexing.py:1558, in _LocIndexer._get_listlike_indexer(self, key, axis)
#    1555 ax = self.obj._get_axis(axis)
#    1556 axis_name = self.obj._get_axis_name(axis)
# -> 1558 keyarr, indexer = ax._get_indexer_strict(key, axis_name)
#    1560 return keyarr, indexer
#
# File c:\Users\RAKSHITA\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File c:\Users\RAKSHITA\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:6249, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6247 if nmissing:
#    6248     if nmissing == len(indexer):
# -> 6249         raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251     not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6252     raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['CS4074', 'CS5057', 'CS2945', 'CS4798', 'CS4424'], dtype='object')] are in the [index]"

# %%
df.head()
# Out:
#   customer_id  tran_amount_2011  tran_amount_2012  tran_amount_2013  \
# 0      CS2945             153.0             516.0             173.0
# 1      CS4074             269.0             429.0             737.0
# 2      CS4798             153.0             536.0             414.0
# 3      CS4424             547.0             380.0             921.0
# 4      CS5057             290.0             235.0             509.0
#
#    tran_amount_2014  tran_amount_2015  transactions_2011  transactions_2012  \
# 0            1029.0              40.0                2.0                7.0
# 1            1027.0               NaN                3.0                6.0
# 2            1001.0              47.0                2.0                7.0
# 3             984.0             101.0                7.0                5.0
# 4             974.0               NaN                4.0                4.0
#
#    transactions_2013  transactions_2014  transactions_2015 First_Transaction  \
# 0                3.0               13.0                1.0         18-May-11
# 1               10.0               15.0                NaN         29-May-11
# 2                6.0               11.0                1.0         01-Jul-11
# 3               13.0               13.0                1.0         25-May-11
# 4                6.0               12.0                NaN         10-Jul-11
#
#   Latest_Transaction
# 0          08-Mar-15
# 1          05-Dec-14
# 2          21-Feb-15
# 3          19-Jan-15
# 4          02-Dec-14
